# %%
# %matplotlib notebook
#import rtlsdr
#from run_an_integration import record_integration
#import subprocess
#from scan_calibrator_signals import calibrate_on_noaa
import numpy as np
from astropy.table import Table
from astropy import units as u
from astropy import constants
import matplotlib.pyplot as plt

# %%
# Sec 1.4 - Test the sofware and connections
#response = subprocess.call([r'C:\ProgramData\Anaconda3\Library\bin\bias_tee_on.bat'])

# Sec 1.5 - Take Calibration data
'''
# Resistor is on 1 secs
for i in range(5):
    record_integration(altitude=-999, azimuth=-999, tint=1,
    observatory_longitude=-82.3, observatory_latitude=29.6,
    obs_type='basic_calibration_resistor_on_1s_'+str(i+1), 
    freqcorr = 60,verbose ='True', timeout_factor=7)

# resistor is on 60 sec
record_integration(altitude=-999, azimuth=-999, tint=60,
observatory_longitude=-82.3, observatory_latitude=29.6,
obs_type='basic_calibration_resistor_on_60s', 
freqcorr = 60,verbose ='True', timeout_factor=7)

# Resistor is off 1 secs
for i in range(5):
    record_integration(altitude=-999, azimuth=-999, tint=1,
    observatory_longitude=-82.3, observatory_latitude=29.6,
    obs_type='basic_calibration_resistor_off_1s_'+str(i+1), 
    freqcorr = 60,verbose ='True', timeout_factor=7)

# resistor is off 60 sec
record_integration(altitude=-999, azimuth=-999, tint=60,
observatory_longitude=-82.3, observatory_latitude=29.6,
obs_type='basic_calibration_resistor_off_60s', 
freqcorr = 60,verbose ='True', timeout_factor=7)

# Resistor is on with LNA 1 secs
for i in range(5):
    record_integration(altitude=-999, azimuth=-999, tint=1,
    observatory_longitude=-82.3, observatory_latitude=29.6,
    obs_type='basic_calibration_lan_resistor_on_1s_'+str(i+1), 
    freqcorr = 60,verbose ='True', timeout_factor=7)

# resistor is on with LNA 60 sec
record_integration(altitude=-999, azimuth=-999, tint=60,
observatory_longitude=-82.3, observatory_latitude=29.6,
obs_type='basic_calibration_lan_resistor_on_60s', 
freqcorr = 60,verbose ='True', timeout_factor=7)

# Resistor is off with LNA 1 secs
for i in range(5):
    record_integration(altitude=-999, azimuth=-999, tint=1,
    observatory_longitude=-82.3, observatory_latitude=29.6,
    obs_type='basic_calibration_lan_resistor_off_1s_'+str(i+1), 
    freqcorr = 60,verbose ='True', timeout_factor=7)

# resistor is off with LNA 60 sec
record_integration(altitude=-999, azimuth=-999, tint=60,
observatory_longitude=-82.3, observatory_latitude=29.6,
obs_type='basic_calibration_lan_resistor_off_60s', 
freqcorr = 60,verbose ='True', timeout_factor=7)
'''
# Sec 1.5.1 - Frequency Calibration
'''
offsets = []

for i in range(10):
    offset = calibrate_on_noaa()[3].value*1e6
    print('This is measurement', i+1, '- Offset =', offset, 'ppm')
    
    offsets.append(offset)
    
mean = np.mean(np.asarray(offsets)) #2.5744 ppm
std = np.std(np.asarray(offsets)) # 0.0 ppm
'''
# Sec 1.5.2 - Plot the Calibration Data
res_on_wo_lna_1s = Table.read('psd_201113_020041_tint1s_sdr0_fswbasic_calibration_resistor_on_1s_1.fits')
res_on_wo_lna_60s = Table.read('psd_201113_020225_tint60s_sdr0_fswbasic_calibration_resistor_on_60s.fits')
res_off_wo_lna_1s = Table.read('psd_201113_020953_tint1s_sdr0_fswbasic_calibration_resistor_off_1s_1.fits')
res_off_wo_lna_60s = Table.read('psd_201113_021136_tint60s_sdr0_fswbasic_calibration_resistor_off_60s.fits')

res_on_w_lna_1s = Table.read('psd_201113_023108_tint1s_sdr0_fswbasic_calibration_lan_resistor_on_1s_1.fits')
res_on_w_lna_60s = Table.read('psd_201113_023251_tint60s_sdr0_fswbasic_calibration_lan_resistor_on_60s.fits')
res_off_w_lna_1s = Table.read('psd_201113_024730_tint1s_sdr0_fswbasic_calibration_lan_resistor_off_1s_1.fits')
res_off_w_lna_60s = Table.read('psd_201113_025357_tint60s_sdr0_fswbasic_calibration_lan_resistor_off_60s.fits')

# plt.figure(dpi=200)

# plt.subplot(1,2,1)
# plt.title('Resistor On Without LNA - 1 sec')
# plt.ylabel('Power 1')
# plt.xlabel('Frequency 1')
# plt.plot(res_on_wo_lna_1s['freq1'], res_on_wo_lna_1s['power1'], 'k-')

# plt.subplot(1,2,2)
# plt.title('Resistor On Without LNA - 1 sec')
# plt.ylabel('Power 2')
# plt.xlabel('Frequency 2')
# plt.plot(res_on_wo_lna_1s['freq2'], res_on_wo_lna_1s['power2'], 'k-')
# plt.tight_layout()
# plt.show()

# plt.subplot(1,2,1)
# plt.title('Resistor On Without LNA - 60 sec')
# plt.ylabel('Power 1')
# plt.xlabel('Frequency 1')
# plt.plot(res_on_wo_lna_60s['freq1'], res_on_wo_lna_60s['power1'], 'k-')

# plt.subplot(1,2,2)
# plt.title('Resistor On Without LNA - 60 sec')
# plt.ylabel('Power 2')
# plt.xlabel('Frequency 2')
# plt.plot(res_on_wo_lna_60s['freq2'], res_on_wo_lna_60s['power2'], 'k-')
# plt.tight_layout()
# plt.show()

# plt.subplot(1,2,1)
# plt.title('Resistor Off Without LNA - 1 sec')
# plt.ylabel('Power 1')
# plt.xlabel('Frequency 1')
# plt.plot(res_off_wo_lna_1s['freq1'], res_off_wo_lna_1s['power1'], 'k-')

# plt.subplot(1,2,2)
# plt.title('Resistor On Without LNA - 1 sec')
# plt.ylabel('Power 2')
# plt.xlabel('Frequency 2')
# plt.plot(res_off_wo_lna_1s['freq2'], res_off_wo_lna_1s['power2'], 'k-')
# plt.tight_layout()
# plt.show()

# plt.subplot(1,2,1)
# plt.title('Resistor Off Without LNA - 60 sec')
# plt.ylabel('Power 1')
# plt.xlabel('Frequency 1')
# plt.plot(res_off_wo_lna_60s['freq1'], res_off_wo_lna_60s['power1'], 'k-')

# plt.subplot(1,2,2)
# plt.title('Resistor Off Without LNA - 60 sec')
# plt.ylabel('Power 2')
# plt.xlabel('Frequency 2')
# plt.plot(res_off_wo_lna_60s['freq2'], res_off_wo_lna_60s['power2'], 'k-')
# plt.tight_layout()
# plt.show()

# plt.subplot(1,2,1)
# plt.title('Resistor On With LNA - 1 sec')
# plt.ylabel('Power 1')
# plt.xlabel('Frequency 1')
# plt.plot(res_on_w_lna_1s['freq1'], res_on_w_lna_1s['power1'], 'k-')

# plt.subplot(1,2,2)
# plt.title('Resistor On With LNA - 1 sec')
# plt.ylabel('Power 2')
# plt.xlabel('Frequency 2')
# plt.plot(res_on_w_lna_1s['freq2'], res_on_w_lna_1s['power2'], 'k-')
# plt.tight_layout()
# plt.show()

# plt.subplot(1,2,1)
# plt.title('Resistor On With LNA - 60 sec')
# plt.ylabel('Power 1')
# plt.xlabel('Frequency 1')
# plt.plot(res_on_w_lna_60s['freq1'], res_on_w_lna_60s['power1'], 'k-')

# plt.subplot(1,2,2)
# plt.title('Resistor On With LNA - 60 sec')
# plt.ylabel('Power 2')
# plt.xlabel('Frequency 2')
# plt.plot(res_on_w_lna_60s['freq2'], res_on_w_lna_60s['power2'], 'k-')
# plt.tight_layout()
# plt.show()

# plt.subplot(1,2,1)
# plt.title('Resistor Off With LNA - 1 sec')
# plt.ylabel('Power 1')
# plt.xlabel('Frequency 1')
# plt.plot(res_off_w_lna_1s['freq1'], res_off_w_lna_1s['power1'], 'k-')

# plt.subplot(1,2,2)
# plt.title('Resistor Off With LNA - 1 sec')
# plt.ylabel('Power 2')
# plt.xlabel('Frequency 2')
# plt.plot(res_off_w_lna_1s['freq2'], res_off_w_lna_1s['power2'], 'k-')
# plt.tight_layout()
# plt.show()

# plt.subplot(1,2,1)
# plt.title('Resistor Off With LNA - 60 sec')
# plt.ylabel('Power 1')
# plt.xlabel('Frequency 1')
# plt.plot(res_off_w_lna_60s['freq1'], res_off_w_lna_60s['power1'], 'k-')

# plt.subplot(1,2,2)
# plt.title('Resistor Off With LNA - 60 sec')
# plt.ylabel('Power 2')
# plt.xlabel('Frequency 2')
# plt.plot(res_off_w_lna_60s['freq2'], res_off_w_lna_60s['power2'], 'k-')
# plt.tight_layout()
# plt.show()

# Sec 1.5.3 - Frequency Switching

# plt.subplot(2,2,1)
# plt.title('Resistor On Without LNA - 1 sec')
# plt.ylabel('fsw_pow')
# plt.xlabel('Frequency 1')
# plt.plot(res_on_wo_lna_1s['freq1'], res_on_wo_lna_1s['fsw_pow'], 'k-')

# plt.subplot(2,2,2)
# plt.title('Resistor On Without LNA - 60 sec')
# plt.ylabel('fsw_pow')
# plt.xlabel('Frequency 1')
# plt.plot(res_on_wo_lna_60s['freq1'], res_on_wo_lna_60s['fsw_pow'], 'k-')

# plt.subplot(2,2,3)
# plt.title('Resistor Off Without LNA - 1 sec')
# plt.ylabel('fsw_pow')
# plt.xlabel('Frequency 1')
# plt.plot(res_off_wo_lna_1s['freq1'], res_off_wo_lna_1s['fsw_pow'], 'k-')

# plt.subplot(2,2,4)
# plt.title('Resistor Off Without LNA - 60 sec')
# plt.ylabel('fsw_pow')
# plt.xlabel('Frequency 1')
# plt.plot(res_off_wo_lna_60s['freq1'], res_off_wo_lna_60s['fsw_pow'], 'k-')
# plt.tight_layout()
# plt.show()

# plt.subplot(2,2,1)
# plt.title('Resistor On With LNA - 1 sec')
# plt.ylabel('fsw_pow')
# plt.xlabel('Frequency 1')
# plt.plot(res_on_w_lna_1s['freq1'], res_on_w_lna_1s['fsw_pow'], 'k-')

# plt.subplot(2,2,2)
# plt.title('Resistor On With LNA - 60 sec')
# plt.ylabel('fsw_pow')
# plt.xlabel('Frequency 1')
# plt.plot(res_on_w_lna_60s['freq1'], res_on_w_lna_60s['fsw_pow'], 'k-')

# plt.subplot(2,2,3)
# plt.title('Resistor Off With LNA - 1 sec')
# plt.ylabel('fsw_pow')
# plt.xlabel('Frequency 1')
# plt.plot(res_off_w_lna_1s['freq1'], res_off_w_lna_1s['fsw_pow'], 'k-')

# plt.subplot(2,2,4)
# plt.title('Resistor Off With LNA - 60 sec')
# plt.ylabel('fsw_pow')
# plt.xlabel('Frequency 1')
# plt.plot(res_off_w_lna_60s['freq1'], res_off_w_lna_60s['fsw_pow'], 'k-')
# plt.tight_layout()
# plt.show()

# %%
# Import science spectra
sci1 = Table.read('psd_201113_133903_tint60s_sdr0_fswscience_loc1_60s.fits')
sci2 = Table.read('psd_201113_134953_tint60s_sdr0_fswscience_loc2_60s.fits')
sci3 = Table.read('psd_201113_135520_tint60s_sdr0_fswscience_loc3_60s.fits')

plt.figure(dpi=100)
plt.title('Science scan 1')
plt.ylabel('bad units')
plt.xlabel('Frequency (Hz)')
plt.plot(sci1['freq2'], sci1['power2'], 'k-')
plt.show()

# Calculate channel width
frequencies = sci2['freq1']
channel_width = (frequencies[1]-frequencies[0])*(u.Hz)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Science image 1

# Convert frequency-switching power to brightness temperature with gain factor
gain = 4.4626444*(10**(15))*(1/(u.Hz*u.J))
calibrated_sci1_T = sci1['fsw_pow']/(gain*channel_width*constants.k_B)
calibrated_sci1_T.unit

# Plot with corrected brightness temperature units
plt.figure(dpi=100)
plt.title('Science scan 1')
plt.ylabel('Brightness Temperature (K)')
plt.xlabel('Frequency (Hz)')
plt.plot(sci1['freq1'], calibrated_sci1_T, 'k-')
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Convert frequency-switching power to brightness temperature with gain factor
gain = 4.4626444*(10**(15))*(1/(u.Hz*u.J))
calibrated_sci2_T = sci2['fsw_pow']/(gain*channel_width*constants.k_B)
calibrated_sci2_T.unit

# Plot with corrected brightness temperature units
plt.figure(dpi=100)
plt.title('Science scan 2')
plt.ylabel('Brightness Temperature (K)')
plt.xlabel('Frequency (Hz)')
plt.plot(sci2['freq1'], calibrated_sci2_T, 'k-')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Convert frequency-switching power to brightness temperature with gain factor
gain = 4.4626444*(10**(15))*(1/(u.Hz*u.J))
calibrated_sci3_T = sci3['fsw_pow']/(gain*channel_width*constants.k_B)
calibrated_sci3_T.unit

# Plot with corrected brightness temperature units
plt.figure(dpi=100)
plt.title(r"Calibrated spectrum 3 ($\ell = +$26$^{\circ}$53')")
plt.ylabel('Brightness Temperature (K)')
plt.xlabel('Frequency (Hz)')
plt.plot(sci3['freq1'], calibrated_sci3_T, 'k-')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fitting_frequencies_indices = np.where((sci1['freq1'] > 1.4201*(10**9)) & (sci1['freq1'] < 1.4206*(10**9)))
good_freq_1 = sci1['freq1'][fitting_frequencies_indices]
good_temp_1 = calibrated_sci1_T[fitting_frequencies_indices]

good_freq_2 = sci2['freq1'][fitting_frequencies_indices]
good_temp_2 = calibrated_sci2_T[fitting_frequencies_indices]

good_freq_3 = sci3['freq1'][fitting_frequencies_indices]
good_temp_3 = calibrated_sci3_T[fitting_frequencies_indices]

good_freq_1 = good_freq_1/(10**9)

coeffs = np.polyfit(good_freq_1, good_temp_1, deg=1)  # determine coefficients for a polynomial of degree 5 to be fit to the data
print(coeffs)  # A*x^5 + B*x^4 + C*x^3 + D*x^2 + E*x + F; very small valued coefficients indicate you’re probably over-fitting
# coeffs[1] = 9.5 * 10**4
polynomial = np.poly1d(coeffs)  # create a poly1d object from our coefficients for np.polyval to use
fitted_temps = np.polyval(polynomial, good_freq_1)  # get the wavelength from the fit for the specified detector coordinates
print(polynomial)
fitted_temps = fitted_temps * u.K

plt.figure(dpi=100)
plt.title('Science scan 1 testing fitting')
plt.ylabel('Brightness Temperature (K)')
plt.xlabel('Frequency (Hz)')
plt.plot(good_freq_1, good_temp_1 - fitted_temps, 'k-')
# plt.plot(good_freq_1, fitted_temps, 'k-')
plt.tight_layout()
plt.show()
# Out:
# [-7191.05947749 10222.39762747]
#
# -7191 x + 1.022e+04
# <img src="data:image/png;base64,..." width="640">

# %%
from scipy.optimize import curve_fit

def gauss(x, a, mu, sigma):
    return a*np.exp(-.5*(x-mu)**2/(sigma**2))

popt, pcov = curve_fit(gauss, xdata=good_freq_1, ydata=good_temp_1-5*u.K, p0=[10,1.42035,0.01]) 
print(popt) 

plt.figure(dpi=100)
plt.plot(good_freq_1,good_temp_1-5*u.K,label='data')
plt.plot(good_freq_1,gauss(good_freq_1,*popt),label='fit')
plt.legend()
plt.title('AAAAA')
plt.xlabel('freqnecy')
plt.ylabel('brightness temp')
plt.show()
# Out:
# [1.20162661e+01 1.42033316e+00 5.05765703e-05]
# <img src="data:image/png;base64,..." width="640">

# %%
# centroiding function
def get_line_centroid(x_bounds, detector_px, flux):
    indcs = (detector_px > x_bounds[0]) & (detector_px < x_bounds[1])  # get the indices where we’re in between the specified bounds
    x_i, m_i = detector_px[indcs], flux[indcs]  # apply the indices to our detector location and flux arrays
    return sum(x_i * m_i) / sum(m_i)  # return the centroid (flux weighted center-of-mass of the line)
print(f’{get_line_centroid([1224, 1271], detector_loc, Ne_collapsed):.2f}’)
